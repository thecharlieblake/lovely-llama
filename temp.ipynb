# %%
from functools import partial

import jax.numpy as jnp
from jax import vmap
from jax.random import PRNGKey, normal, split

from utils import BatchException, batch_axes

# %%
k = PRNGKey(1472)
k, k_a, k_b = split(k, 3)
a = normal(k_a, (4, 5))
b = normal(k_b, (6, 5))

# %%
normal(k_b, ())
# Out:
# Array(0.3865451, dtype=float32)

# %%
def dummy(x: Float[Array, "dim"]):
    assert len(x.shape) == 1, x.shape
    return x

# %%
dummy(a[0,0])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 dummy(a[0,0])
#
# Cell In[139], line 2, in dummy(x)
#       1 def dummy(x):
# ----> 2     assert len(x.shape) == 1, x.shape
#       3     return x
#
# AssertionError: ()

# %%
vmap(dummy)(a)
# Out:
# Array([[ 1.8967149 , -0.83555925, -0.34839267,  0.9181132 , -0.9482927 ],
#        [ 0.38502958, -0.11291686,  0.45518556, -1.4861697 , -1.5660759 ],
#        [-0.14580996,  1.3000145 , -1.0476174 , -1.1174875 , -1.9110572 ],
#        [ 0.15925422, -1.0280808 ,  0.5877574 , -0.85032856, -0.57334125]],      dtype=float32)

# %%
batch_axes(x="batch_1 dim")(dummy)(a[0])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 batch_axes(x="batch_1")(dummy)(a[0])
#
# Cell In[127], line 2, in dummy(x)
#       1 def dummy(x):
# ----> 2     assert x.shape == (), x.shape
#       3     return x
#
# AssertionError: (5,)

# %%
batch_axes(x="batch_1 batch_2")(dummy)(a)
